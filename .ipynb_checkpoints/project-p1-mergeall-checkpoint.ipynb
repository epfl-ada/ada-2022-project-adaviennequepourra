# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import math
import datetime as dt
import nltk
#nltk.download('omw-1.4')
from pattern.en import sentiment
import re
import scipy
import statsmodels.stats.multitest as multiple

# %% [markdown]
# ## Load, filter and transform the data

# %%
# load the data

data_folder = './MovieSummaries/'
plots = pd.read_csv(data_folder+'plot_summaries.txt', sep='	', header=None, names=["wiki_id", "summary"])
movie_meta = pd.read_csv(data_folder+'movie.metadata.tsv', sep='	', header=None, names=["wiki_id", "freebase_id", "movie_name", "release_date", "revenue", "runtime", "languages", "countries", "genres"])
char_meta = pd.read_csv(data_folder+'character.metadata.tsv', sep='	', header=None, names=["wiki_id", "freebase_id", "release_date", "character_name", "birth", "gender", "height", "ethnicity", "actor_name", "actor_age", "character_actor_map", "character_id", "actor_id"])

# we dont load clusters of latent personas because we are not gonna use them

#tvtropes_clusters = pd.read_csv(data_folder+'tvtropes.clusters.txt')
#name_clusters = pd.read_csv(data_folder+'name.clusters.txt')

# %%
summaries = plots.copy() # this is for the sentiment analysis part

# %%
# merge plot summaries database with movie meta database

merged = plots.merge(movie_meta, on="wiki_id", how="right")
merged.head()
# Out:
#     wiki_id                                            summary freebase_id  \
# 0    975900  Set in the second half of the 22nd century, th...   /m/03vyhn
# 1   3196793                                                NaN   /m/08yl5d
# 2  28463795                                                NaN  /m/0crgdbh
# 3   9363483  A series of murders of rich young women throug...  /m/0285_cd
# 4    261236  Eva, an upper class housewife, becomes frustra...   /m/01mrr1
#
#                                           movie_name release_date     revenue  \
# 0                                     Ghosts of Mars   2001-08-24  14010832.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16         NaN
# 2                                        Brun bitter         1988         NaN
# 3                                   White Of The Eye         1987         NaN
# 4                                  A Woman in Flames         1983         NaN
#
#    runtime                           languages  \
# 0     98.0  {"/m/02h40lc": "English Language"}
# 1     95.0  {"/m/02h40lc": "English Language"}
# 2     83.0  {"/m/05f_3": "Norwegian Language"}
# 3    110.0  {"/m/02h40lc": "English Language"}
# 4    106.0   {"/m/04306rv": "German Language"}
#
#                                    countries  \
# 0  {"/m/09c7w0": "United States of America"}
# 1  {"/m/09c7w0": "United States of America"}
# 2                     {"/m/05b4w": "Norway"}
# 3             {"/m/07ssc": "United Kingdom"}
# 4                    {"/m/0345h": "Germany"}
#
#                                               genres
# 0  {"/m/01jfsb": "Thriller", "/m/06n90": "Science...
# 1  {"/m/02n4kr": "Mystery", "/m/03bxz7": "Biograp...
# 2  {"/m/0lsxr": "Crime Fiction", "/m/07s9rl0": "D...
# 3  {"/m/01jfsb": "Thriller", "/m/0glj9q": "Erotic...
# 4                            {"/m/07s9rl0": "Drama"}

# %%
# change dicts into values

merged["languages"] = merged.apply(lambda x: list(eval(x["languages"]).values()), axis=1)
merged["countries"] = merged.apply(lambda x: list(eval(x["countries"]).values()), axis=1)
merged["genres"] = merged.apply(lambda x: list(eval(x["genres"]).values()), axis=1)

# %%
#fixing outlier and converting to datetime

merged.summary = merged.summary.fillna('')
merged.loc[merged['wiki_id']== 29666067, 'release_date'] = dt.datetime(2010, 12, 2)
dates = pd.to_datetime(merged['release_date'])
merged['release_date'] = dates


#for sentiment analysis
df_sentiment = merged.copy()
#for merging with additional datasets
df_additional = merged.copy()
df_additional = df_additional[df_additional['release_date'].notna()]  
#for plotting even more 
df = merged.copy()

# %% [markdown]
# _Please note that as we merged our 4 jupyter notebooks for the milestone 2, we created multiple copies of the dataset in order to make it simpler to execute and understand._

# %% [markdown]
# ## Themes and genres evolution analysis

# %%
merged.sort_values(by="revenue", ascending=False)
merged.head()
# Out:
#     wiki_id                                            summary freebase_id  \
# 0    975900  Set in the second half of the 22nd century, th...   /m/03vyhn
# 1   3196793                                                      /m/08yl5d
# 2  28463795                                                     /m/0crgdbh
# 3   9363483  A series of murders of rich young women throug...  /m/0285_cd
# 4    261236  Eva, an upper class housewife, becomes frustra...   /m/01mrr1
#
#                                           movie_name release_date     revenue  \
# 0                                     Ghosts of Mars   2001-08-24  14010832.0
# 1  Getting Away with Murder: The JonBenét Ramsey ...   2000-02-16         NaN
# 2                                        Brun bitter   1988-01-01         NaN
# 3                                   White Of The Eye   1987-01-01         NaN
# 4                                  A Woman in Flames   1983-01-01         NaN
#
#    runtime             languages                   countries  \
# 0     98.0    [English Language]  [United States of America]
# 1     95.0    [English Language]  [United States of America]
# 2     83.0  [Norwegian Language]                    [Norway]
# 3    110.0    [English Language]            [United Kingdom]
# 4    106.0     [German Language]                   [Germany]
#
#                                               genres
# 0  [Thriller, Science Fiction, Horror, Adventure,...
# 1   [Mystery, Biographical film, Drama, Crime Drama]
# 2                             [Crime Fiction, Drama]
# 3  [Thriller, Erotic thriller, Psychological thri...
# 4                                            [Drama]

# %%
m1 = merged.dropna(subset=["release_date"])
m1.sort_values(by="release_date", ascending=False)
# Out:
#         wiki_id summary freebase_id  \
# 34022  23124260          /m/064mmw7
# 30275  27554912          /m/0c03gcc
# 64862   3139382           /m/08tyfg
# 51429  25813358          /m/0gmbk1g
# 8307   24179103          /m/0jwx0kc
# ...         ...     ...         ...
# 25984    644824           /m/02_1qn
# 60249  22770416          /m/0gj9h_4
# 53907   6431996           /m/0g53t3
# 38764  12170539          /m/02vs8rb
# 57963   1082508           /m/044ggd
#
#                                               movie_name release_date  \
# 34022                                 Jeepers Creepers 4   2016-06-08
# 30275                                    Kung Fu Panda 3   2016-03-18
# 64862                                       Battle Angel   2016-01-01
# 51429                                           Avatar 2   2015-01-01
# 8307                                          I, Robot 2   2015-01-01
# ...                                                  ...          ...
# 25984                                   Dickson Greeting   1891-01-01
# 60249                          London's Trafalgar Square   1890-01-01
# 53907                                Monkeyshines, No. 1   1890-01-01
# 38764  Leisurely Pedestrians, Open Topped Buses and H...   1889-01-01
# 57963                              Roundhay Garden Scene   1888-01-01
#
#        revenue  runtime                        languages  \
# 34022      NaN      NaN                               []
# 30275      NaN      NaN                               []
# 64862      NaN      NaN               [English Language]
# 51429      NaN      NaN               [English Language]
# 8307       NaN      NaN                               []
# ...        ...      ...                              ...
# 25984      NaN     0.05                               []
# 60249      NaN      NaN                    [Silent film]
# 53907      NaN      NaN                    [Silent film]
# 38764      NaN      NaN  [Silent film, English Language]
# 57963      NaN     0.03                    [Silent film]
#
#                         countries  \
# 34022  [United States of America]
# 30275                          []
# 64862  [United States of America]
# 51429  [United States of America]
# 8307                           []
# ...                           ...
# 25984  [United States of America]
# 60249            [United Kingdom]
# 53907  [United States of America]
# 38764            [United Kingdom]
# 57963            [United Kingdom]
#
#                                                   genres
# 34022                                 [Thriller, Horror]
# 30275                                                 []
# 64862  [Thriller, Science Fiction, Action, Romance Film]
# 51429      [Science Fiction, Action, Fantasy, Adventure]
# 8307                                   [Science Fiction]
# ...                                                  ...
# 25984                                [Short Film, Indie]
# 60249                          [Short Film, Silent film]
# 53907                                      [Silent film]
# 38764  [Short Film, Silent film, Indie, Black-and-white]
# 57963  [Short Film, Silent film, Indie, Black-and-white]
#
# [74839 rows x 10 columns]

# %%
#df = df[df["release_date"].dt.year < 1915]
long_movies = merged[merged.genres.apply(lambda x : not "Short Film" in x)]
long_movies_us = merged[merged.countries.apply(lambda x : "United States of America" in x)]
long_movies_us
# Out:
#         wiki_id                                            summary  \
# 0        975900  Set in the second half of the 22nd century, th...
# 1       3196793
# 5      13696889
# 7      10408933
# 10       175026
# ...         ...                                                ...
# 81725   1918494  Havoc is wrought on the inhabitants of a small...
# 81726    664006  Jennifer Haines  is an up-and-coming Chicago a...
# 81727  24209227
# 81736  35228177  Two former National Oceanic Atmospheric Admini...
# 81738   9971909
#
#       freebase_id                                         movie_name  \
# 0       /m/03vyhn                                     Ghosts of Mars
# 1       /m/08yl5d  Getting Away with Murder: The JonBenét Ramsey ...
# 5      /m/03cfc81                                      The Gangsters
# 7      /m/02qc0j7                           Alexander's Ragtime Band
# 10      /m/017n1p                                      Sarah and Son
# ...           ...                                                ...
# 81725   /m/0660qx                                     State and Main
# 81726   /m/030xw6                                      Guilty as Sin
# 81727  /m/07k5mlk                   The Time, the Place and the Girl
# 81736  /m/0j7hxnt                           Mermaids: The Body Found
# 81738  /m/02pygw1                                  Another Nice Mess
#
#       release_date     revenue  runtime                             languages  \
# 0       2001-08-24  14010832.0     98.0                    [English Language]
# 1       2000-02-16         NaN     95.0                    [English Language]
# 5       1913-05-29         NaN     35.0       [Silent film, English Language]
# 7       1938-08-16   3600000.0    106.0                    [English Language]
# 10      1930-01-01         NaN     86.0                    [English Language]
# ...            ...         ...      ...                                   ...
# 81725   2000-08-26   6944471.0    106.0  [Italian Language, English Language]
# 81726   1993-06-04  22886222.0    107.0                                    []
# 81727   1946-01-01         NaN    105.0                    [English Language]
# 81736   2011-03-19         NaN    120.0                    [English Language]
# 81738   1972-09-22         NaN     66.0                    [English Language]
#
#                                 countries  \
# 0              [United States of America]
# 1              [United States of America]
# 5              [United States of America]
# 7              [United States of America]
# 10             [United States of America]
# ...                                   ...
# 81725  [France, United States of America]
# 81726          [United States of America]
# 81727          [United States of America]
# 81736          [United States of America]
# 81738          [United States of America]
#
#                                                   genres
# 0      [Thriller, Science Fiction, Horror, Adventure,...
# 1       [Mystery, Biographical film, Drama, Crime Drama]
# 5      [Short Film, Silent film, Indie, Black-and-whi...
# 7                     [Musical, Comedy, Black-and-white]
# 10                              [Drama, Black-and-white]
# ...                                                  ...
# 81725                        [Parody, Americana, Comedy]
# 81726  [Thriller, Erotic thriller, Psychological thri...
# 81727               [Comedy film, Romance Film, Musical]
# 81736                                            [Drama]
# 81738                                   [Satire, Comedy]
#
# [34408 rows x 10 columns]

# %%
# return 1 when a set of words is used in the plot summary

def summary_contains_words(summary, words):
    if str(summary) == "nan":
        return 0
    for word in words:
        strings = summary.lower().split(" ")
        if word in summary.lower().split(" "):
            return 1
    return 0

# %%
# How often do the words related to war show up in plot summaries by year ?

war_related = ["war", "warfare", "battle", "military", "soldier", "jihad", "crusade"]
#merged = merged[merged["release_date"].dt.year < 2015]
merged["war_related"] = merged.apply(lambda x: summary_contains_words(x["summary"], war_related), axis=1)
num_of_movies_by_year = merged.groupby(merged.release_date.dt.year)['wiki_id'].count()
war_movies = merged[merged.war_related.apply(lambda x : x == 1)]
war_movies_by_year = war_movies.groupby(war_movies.release_date.dt.year)['wiki_id'].count()
war_movies_by_year_proportion = war_movies_by_year/num_of_movies_by_year
war_movies_proportion_without_nan = war_movies_by_year_proportion.fillna(0)
plt.plot(war_movies_proportion_without_nan)
plt.xlabel("Year")
plt.ylabel("Proportion of films where summary mentions topic of war")
plt.title("Proportion of films related to war by year")
# Out:
# Text(0.5, 1.0, 'Proportion of films related to war by year')

# %%
# How often do the words related to terrorism show up in plot summaries by year ?

terror_related = ["terrorism", "terrorist"]
merged["war_related"] = merged.apply(lambda x: summary_contains_words(x["summary"], terror_related), axis=1)
num_of_movies_by_year = merged.groupby(merged.release_date.dt.year)['wiki_id'].count()
war_movies = merged[merged.war_related.apply(lambda x : x == 1)]
war_movies_by_year = war_movies.groupby(war_movies.release_date.dt.year)['wiki_id'].count()
war_movies_by_year_proportion = war_movies_by_year/num_of_movies_by_year
war_movies_proportion_without_nan = war_movies_by_year_proportion.fillna(0)
plt.plot(war_movies_proportion_without_nan)
plt.xlabel("Year")
plt.ylabel("Proportion of films where summary mentions terrorism")
plt.title("Proportion of terrorism related Films by year")
# Out:
# Text(0.5, 1.0, 'Proportion of terrorism related Films by year')

# %%
merged = merged[merged["release_date"].dt.year < 1980]
number_of_movies = merged.groupby(merged.release_date.dt.year)['wiki_id'].count()
plt.plot(number_of_movies)
plt.xlabel("Year")
plt.ylabel("Number of films")
plt.title("Number of films produced by year")
# Out:
# Text(0.5, 1.0, 'Number of films produced by year')

# %%
# helpers for plotting

def plot_proportion(proportion,title, y_label = "proportion"):
    proportion.plot.bar(rot=45, figsize=(10, 6))
    plt.locator_params(nbins=20)
    plt.ylabel(y_label)
    plt.title(title)
    return proportion

def create_proportion_by_year(number_of_films):
    tot_by_year = df.groupby(df.release_date.dt.year)['wiki_id'].count()
    number_of_films_by_year = number_of_films.groupby(number_of_films.release_date.dt.year)['wiki_id'].count()
    number_of_films_by_year = number_of_films_by_year/tot_by_year
    return number_of_films_by_year.apply(lambda x: 0 if np.isnan(x) else x)

def proportion_of_movies_with_war_in_summary(df, title):
    pd.options.mode.chained_assignment = None
    war_movies = df[df.summary.str.lower().str.contains('war')]
    proportion_summary = create_proportion_by_year(war_movies)
    return plot_proportion(proportion_summary, title)

def proportion_of_nazis_in_summary(df, title):
    pd.options.mode.chained_assignment = None
    movies_with_nazis = df[df.summary.str.lower().str.contains('nazi')]
    nazis_by_year = create_proportion_by_year(movies_with_nazis)
    return plot_proportion(nazis_by_year, title)

def proportion_of_war_movies(df, title):
    war_movies_genre = df[df.genres.apply(lambda x :'War film' in x)]
    proportion_genre = create_proportion_by_year(war_movies_genre)
    return plot_proportion(proportion_genre, title)

def proportion_of_anti_war_movies(df, title):
    anti_war_movies_genre = df[df.genres.apply(lambda x :'Anti-war' in x)]
    proportion_anti_genre = create_proportion_by_year(anti_war_movies_genre)
    return plot_proportion(proportion_anti_genre, title)

def p_value_for_diff_years(war_movies, ind, WWII_ind):
    WWII=war_movies.loc[(war_movies.index <= WWII_ind[1]) & (war_movies.index >= WWII_ind[0])]
    p_values = []
    for lower, upper in ind:
        other = war_movies.loc[(war_movies.index <= upper) & (war_movies.index >= lower)]
        stat, p_value = scipy.stats.ttest_ind(WWII, other)
        p_values.append(p_value)
    return p_values

# %%
nazis_in_summaries=proportion_of_nazis_in_summary(df, "Proportion of movies that have the word nazi in the summary by year")

# %%
war_movies_by_year_summary=proportion_of_movies_with_war_in_summary(df, "Proportion of movies that have the word war in the summary by year")

# %%
war_movies_by_year = proportion_of_war_movies(df, "Proportion of War Films by year")

# %%
#We're gonna compare the difference of movie production of movies made during 1939 and 1945 and movies made at other times
#We're gonna calulate the p-values of movies with the word 'war' in them, or movies with the word 'nazi' in them and
#finally just war movies in general
np.seterr(divide = 'ignore') 
WWII_ind = (1939,1945)
a =np.arange(1918, 2000, 7)
b = np.arange(1924, 2007, 7)
indexes = list(zip(a,b))
p_values_genres = p_value_for_diff_years(war_movies_by_year, indexes, WWII_ind)
p_values_summaries = p_value_for_diff_years(war_movies_by_year_summary, indexes, WWII_ind)
p_values_nazis = p_value_for_diff_years(nazis_in_summaries, indexes, WWII_ind)
multi_genres = multiple.multipletests(p_values_genres)
multi_summaries = multiple.multipletests(p_values_summaries)
multi_nazis = multiple.multipletests(p_values_nazis)

# %%
def print_p_values(indexes, multi_p_val, title):
    print(title)
    return list(zip(indexes, multi_p_val[1], multi_p_val[0]))

# %%
print_p_values(indexes, multi_summaries, "Statistical significance of movies containing the word war :")
# Out:
# Statistical significance of movies containing the word war :
# [((1918, 1924), 1.294082930452511e-05, True),
#  ((1925, 1931), 0.002208866460544339, True),
#  ((1932, 1938), 0.032118214178689306, True),
#  ((1939, 1945), 1.0, False),
#  ((1946, 1952), 0.9949266231388167, False),
#  ((1953, 1959), 0.9748151494174879, False),
#  ((1960, 1966), 0.7469133110922115, False),
#  ((1967, 1973), 0.3611297707686104, False),
#  ((1974, 1980), 0.7469133110922115, False),
#  ((1981, 1987), 0.7469133110922115, False),
#  ((1988, 1994), 0.7469133110922115, False),
#  ((1995, 2001), 0.4135888300292103, False)]

# %%
print_p_values(indexes, multi_genres, "Statistical significance of war movies :")
# Out:
# Statistical significance of war movies :
# [((1918, 1924), 0.004987610336473554, True),
#  ((1925, 1931), 0.01565773050913876, True),
#  ((1932, 1938), 0.012135187281185301, True),
#  ((1939, 1945), 1.0, False),
#  ((1946, 1952), 0.02008493171568515, True),
#  ((1953, 1959), 0.050860719323774846, False),
#  ((1960, 1966), 0.050860719323774846, False),
#  ((1967, 1973), 0.02008493171568515, True),
#  ((1974, 1980), 0.01565773050913876, True),
#  ((1981, 1987), 0.01565773050913876, True),
#  ((1988, 1994), 0.011522546440642939, True),
#  ((1995, 2001), 0.012135187281185301, True)]

# %%
print_p_values(indexes, multi_nazis, "Statistical significance of movies containing the word Nazi :")
# Out:
# Statistical significance of movies containing the word Nazi :
# [((1918, 1924), 0.006514978486622691, True),
#  ((1925, 1931), 0.006536794305784201, True),
#  ((1932, 1938), 0.008363558946680305, True),
#  ((1939, 1945), 1.0, False),
#  ((1946, 1952), 0.026419128662217507, True),
#  ((1953, 1959), 0.026419128662217507, True),
#  ((1960, 1966), 0.026419128662217507, True),
#  ((1967, 1973), 0.026419128662217507, True),
#  ((1974, 1980), 0.026419128662217507, True),
#  ((1981, 1987), 0.026419128662217507, True),
#  ((1988, 1994), 0.02114796376754459, True),
#  ((1995, 2001), 0.02114796376754459, True)]

# %% [markdown]
# We can see that for a surface search on the summaries we can't find a statistically significant difference between the movies made during the world war two and after.
#
# But we can find a statistical difference between war movies made during World War II and at other times.
#
# (It isn't statistically significant if we take a threshold at 0.05, but if we take a threshold slightly higher like 0.06, then it is statistically significant. So we can say that it is mostly significant).
#
# Also the word Nazi is used significantly more in plots during the world war, which makes sense considering the context, although we might need to look if the movies are made in the US or in Germany, as this might have a different meaning.

# %%
usDf = df[df.countries.apply(lambda x :'United States of America' in x)]
germanyDf = df[df.countries.apply(lambda x :'Germany' in x)]

# %%
german_Nazi_movies = proportion_of_nazis_in_summary(germanyDf, "Proportion of German movies that have the word nazi in their plots by year")

# %%
american_Nazi_movies = proportion_of_nazis_in_summary(usDf, "Proportion of American movies that have the word nazi in their plots by year")

# %%
np.seterr(divide = 'ignore') 
p_val_american_nazi = multiple.multipletests(p_value_for_diff_years(american_Nazi_movies, indexes, WWII_ind), alpha=0.06)

print_p_values(indexes, p_val_american_nazi, "Statistical significance of American movies comtaining the word Nazi")
# Out:
# Statistical significance of American movies comtaining the word Nazi
# [((1918, 1924), 0.02883675027900545, True),
#  ((1925, 1931), 0.02883675027900545, True),
#  ((1932, 1938), 0.02883675027900545, True),
#  ((1939, 1945), 1.0, False),
#  ((1946, 1952), 0.05348676746605141, True),
#  ((1953, 1959), 0.05348676746605141, True),
#  ((1960, 1966), 0.05348676746605141, True),
#  ((1967, 1973), 0.05348676746605141, True),
#  ((1974, 1980), 0.05348676746605141, True),
#  ((1981, 1987), 0.05348676746605141, True),
#  ((1988, 1994), 0.05348676746605141, True),
#  ((1995, 2001), 0.05348676746605141, True)]

# %%
p_val_german_nazi = multiple.multipletests(p_value_for_diff_years(german_Nazi_movies, indexes, WWII_ind), alpha=0.06)
np.seterr(divide = 'ignore') 
print_p_values(indexes, p_val_german_nazi, "Statistical significance of German movies comtaining the word Nazi")
# Out:
# Statistical significance of German movies comtaining the word Nazi
# [((1918, 1924), 0.6481911410922307, False),
#  ((1925, 1931), 0.9630491010486496, False),
#  ((1932, 1938), 0.9998217320596614, False),
#  ((1939, 1945), 1.0, False),
#  ((1946, 1952), 0.9998217320596614, False),
#  ((1953, 1959), 0.923270065052497, False),
#  ((1960, 1966), 0.9732109342463573, False),
#  ((1967, 1973), 0.9630491010486496, False),
#  ((1974, 1980), 0.9998217320596614, False),
#  ((1981, 1987), 0.9529339359660152, False),
#  ((1988, 1994), 0.9998217320596614, False),
#  ((1995, 2001), 0.9981251210479027, False)]

# %% [markdown]
# We can see that the difference of plots that use the word Nazi in American movies during world war II is significant, but not for movies made in Germany.
#
# This doesn't make sense considering the context of the time, but might make sense considering the bias of the data that mostly contains american movies.
#
# Also we might notice that German movies contain way more references to Nazis and that they appear already in 1930 whereas in American movies they first appear in 1939.
#
# We should increase the size of German movies during and after World War II in the dataset to continue this analysis.

# %%
number_of_German_movies =plot_proportion(germanyDf.groupby(germanyDf.release_date.dt.year)['wiki_id'].count(), 'Number of German movies by year', y_label="number of films")

# %% [markdown]
# ## Sentiment analysis

# %% [markdown]
# The score of sentiment analysis are between -1 (unhappy) and 1 (joyful).

# %% [markdown]
# Note that the analysis made here are not complete or on a very deep level, but the goal is to show what we can work with, and to prove that we could extract meaningful informations.

# %%
# data preparation for sentiment analysis

total_length = len(summaries) # number of samples
summary_with_war = summaries[summaries['summary'].str.contains('war')] # select only the data with 'war' in it
with_war_length = len(summary_with_war)
print('There is', with_war_length, 'movies with world war in the summary')
print('pourcentage of movies with the word war in the summary = ', len(summary_with_war)/total_length * 100)
# Out:
# There is 14079 movies with world war in the summary
# pourcentage of movies with the word war in the summary =  33.281327565420895

# %%
# compute average sentiment of war movies

df_sentiment_forall = df_sentiment.copy()
print(len(df_sentiment))
df_sentiment['is_war_film'] = df_sentiment['genres'].apply(lambda x: 'War film' in x) # add a indicator of war movie or not
df_sentiment = df_sentiment[df_sentiment.is_war_film] # select only the war movies
df_sentiment['sentiment'] = df_sentiment['summary'].apply(lambda x: sentiment(x)) # apply sentiment analysis over the summaries
df_sentiment['sentiment'] = df_sentiment['sentiment'].apply(lambda x: x[0]) # select only the sentiment score
df_sentiment = df_sentiment[(df_sentiment['sentiment'] != 0)] # take data only where there is a summary
average_sentiment = df_sentiment['sentiment'].sum() / len(df_sentiment)
print("average sentiment :", average_sentiment)
# Out:
# 81741
# average sentiment : 0.02891878364859746

# %%
# compute average sentiment of all movies

df_sorted = df_sentiment_forall.sort_values(by=['release_date'])
df_sorted['sentiment'] = df_sorted['summary'].apply(lambda x: sentiment(x))
df_sorted['sentiment'] = df_sorted['sentiment'].apply(lambda x: x[0])
df_sorted = df_sorted[(df_sorted['sentiment'] != 0)]
# Now we have obtained all sentiment scores for all movies.

def calculate_average_sentiment(df):
    return df['sentiment'].sum() / len(df)

av_of_all_movies = calculate_average_sentiment(df_sorted)
print('the average is :', av_of_all_movies)

df_sorted.sample(5)
# Out:
# the average is : 0.04721542729080025
#         wiki_id                                            summary  \
# 68717   6981094  Near the end of the Korean War a new replaceme...
# 46334  22884121  Beaten and expelled by African villagers for t...
# 68483   3747264  Waitress-turned-Broadway star Mabel O'Dare  an...
# 61915   3755662  Jimmie Shannon  wants to be a bachelor forever...
# 35608  29699054  Nirbhay is an action film in Hindi language, w...
#
#       freebase_id      movie_name release_date     revenue  runtime  \
# 68717   /m/0gzs2r        War Hunt   1962-05-01         NaN     81.0
# 46334  /m/063zyf7    Mister Moses   1965-05-12         NaN    116.0
# 68483   /m/09ytwy  Cain and Mabel   1936-01-01         NaN     90.0
# 61915   /m/09z8d1    The Bachelor   1999-11-05  36911617.0    102.0
# 35608  /m/0fq38wk         Nirbhay   1996-02-26         NaN    135.0
#
#                                   languages                   countries  \
# 68717                                    []  [United States of America]
# 46334                    [English Language]  [United States of America]
# 68483                    [English Language]  [United States of America]
# 61915  [English Language, Spanish Language]  [United States of America]
# 35608                      [Hindi Language]                     [India]
#
#                                                   genres  sentiment
# 68717        [Action/Adventure, Action, Drama, War film]  -0.024697
# 46334                                 [Drama, Adventure]  -0.071825
# 68483  [Romantic comedy, Romance Film, Musical, Comed...   0.076783
# 61915            [Romantic comedy, Romance Film, Comedy]   0.090002
# 35608                                           [Action]   0.100000

# %% [markdown]
# The average over all movies is 0.047 (this is 1.6 times more 'happy' than the war movies)

# %% [markdown]
# #### Let's see the average sentiment analysis over different countries and different periods.

# %%
# helper functions for sentiment analysis

def get_country_movies(df, country):
    return df[df.countries.apply(lambda x : country in x)]

def create_history_span(df, begin, end):
    return df.loc[(df.release_date.dt.year < end) & (df.release_date.dt.year > begin)]

def plot_sentiment_country_span(span):
    fig, axs = plt.subplots(figsize=(25, 5))
    sentiments = span.groupby(span.release_date.dt.year)['sentiment'].mean()
    
    sentiments.plot(kind='bar', rot=90, ax=axs)
    plt.xlabel("Year")
    plt.ylabel("Sentiment score")
    plt.title("Mean sentiment score per year")

# %% [markdown]
# ## Sentiment analysis plots

# %%
# plotting USA sentiment 

df_sorted_us = get_country_movies(df_sorted, 'United States of America')
print
begin = 1900
end = 1990
span_us = create_history_span(df_sorted_us, begin, end)
plot_sentiment_country_span(span_us)
print('Average sentiment of all movies in usa :', calculate_average_sentiment(df_sorted_us))
# Out:
# Average sentiment of all movies in usa : 0.04044205833529916

# %% [markdown]
# We can see that there is a slight decrease in sentiment at a period  that matches the end of the Vietnam War.

# %%
# plotting Germany sentiment 

df_sorted_ge = get_country_movies(df_sorted, 'Germany')

begin = 1900
end = 1990
span_ge = create_history_span(df_sorted_ge, begin, end)

plot_sentiment_country_span(span_ge)

print('Average sentiment of all movies in germany :', calculate_average_sentiment(df_sorted_ge))
# Out:
# Average sentiment of all movies in germany : 0.04266313626282843

# %% [markdown]
# We can see that there is a big decrease in sentiment (more unhappy and dark movies) at a period that matches the end WW2.

# %%
# plotting France sentiment 

df_sorted_fr = get_country_movies(df_sorted, 'France')

begin = 1900
end = 1990
span_fr = create_history_span(df_sorted_fr, begin, end)

plot_sentiment_country_span(span_fr)

print('Average sentiment of all movies in france :', calculate_average_sentiment(df_sorted_fr))
# Out:
# Average sentiment of all movies in france : 0.05001018041703206

# %% [markdown]
# We can see that there is a big decrease in sentiment (more unhappy and dark movies) at a period that matches the end WW1.

# %%
# plotting Italy sentiment 

df_sorted_it = get_country_movies(df_sorted, 'Italy')

begin = 1900
end = 1990
span_it = create_history_span(df_sorted_it, begin, end)

plot_sentiment_country_span(span_it)

print('Average sentiment of all movies in Italy :', calculate_average_sentiment(df_sorted_it))
# Out:
# Average sentiment of all movies in Italy : 0.03857576341424649

# %% [markdown]
# We can see that there is a decrease in sentiment (more unhappy and dark movies) at a period that matches the end WW2 (1945, 1946).

# %% [markdown]
# ## Creation of a dataset with plot summmaries

# %%
# import dataset scraped from wikipedia

df_wikipedia = pd.read_json('with_plot.txt', lines=True)
df_wikipedia = df_wikipedia[['id', 'directors', 'plot']]
df_wikipedia.rename(columns={'id':'wiki_id', 'plot':'summary'}, inplace=True)
df_wikipedia = df_wikipedia[df_wikipedia['summary'].notna()] # only keep rows that have a plot summary

# %%
# Method for a first cleanup of the data ; this will need more work in the future

def remove_html(line):
    CLEANR = re.compile('<!--.*--') 
    CLEANR2 = re.compile('<ref.*</ref') 
    CLEANR3 = re.compile('<Ref.*</ref')
    x = re.sub(CLEANR, '', line)
    x = re.sub(CLEANR3, '', x)
    x = re.sub(CLEANR2, '', x)
    x = x.replace('\n', '') # remove newlines
    return x

# remove html references in plot summaries
df_wikipedia['summary'] = df_wikipedia['summary'].apply(lambda x : remove_html(x))
df_wikipedia.head()
# Out:
#    wiki_id             directors  \
# 0      330    [[[Ventura Pons]]]
# 1     3217       [[[Sam Raimi]]]
# 2     3333  [[[D. W. Griffith]]]
# 3     3746    [[[Ridley Scott]]]
# 4     3837      [[[Mel Brooks]]]
#
#                                              summary
# 0  In order to prepare herself to play a role com...
# 1  Having been accidentally transported to the [[...
# 2  The film consists of two parts of similar leng...
# 3  [[Hatnote|Note: Since there are several versio...
# 4  On the [[American frontier]] of 1874, a new ra...

# %%
# Method that takes the wikipedia summary if the CMU database doesn't provide one

def pick_better_plot(x):
    if x.summary_x == '':
        if x['summary_y'] == '':
            return np.nan
        else:
            return x['summary_y']
    else:
        return x['summary_x']

# since we base our analysis on release dates, we remove films with no release date
df_additional = df_additional[df_additional['release_date'].notna()]  
print(len(df_additional))
    
summary_df = pd.merge(df_additional,df_wikipedia,on='wiki_id',how='left')
summary_df['summary_x'] = summary_df['summary_x'].fillna('')
summary_df['summary_y'] = summary_df['summary_y'].fillna('')

# create new column with the wikipedia summary if CMU doesn't provide one
summary_df['summary'] = summary_df.apply(lambda x : pick_better_plot(x),axis=1)

# keep only rows that have a summary
summary_df = summary_df[summary_df['summary'].notna()]
summary_df = summary_df.drop(columns=['summary_x', 'summary_y'])
summary_df.sample(10)
# Out:
# 74839
#         wiki_id freebase_id                    movie_name release_date  \
# 49623   7638932   /m/0kvc_0               Promise Me This   2007-05-01
# 67249  13950959  /m/03cp4cn                Shutter Island   2010-02-13
# 14855  16718585  /m/04043ls                       Armored   2009-12-04
# 69732  20254951  /m/04zzhdp          That Sinking Feeling   1980-01-01
# 54680  13977978  /m/03cp_5k           Battal Gazi Destanı   1971-01-01
# 22415  23319831  /m/0661067                  Our Very Own   1950-07-27
# 28282  10640837  /m/02qk_bh                  Rajathi Raja   1989-01-01
# 28216    193845   /m/01bj7c        The Three Faces of Eve   1957-09-23
# 70825  32005795  /m/0gx1kcd                 Blind Company   2010-04-28
# 59819   6563355   /m/0gbrk8  Amityville: A New Generation   1993-01-01
#
#            revenue  runtime                            languages  \
# 49623          NaN    127.0   [Serbo-Croatian, Serbian language]
# 67249  294804195.0    138.0  [English Language, German Language]
# 14855          NaN     88.0                   [English Language]
# 69732          NaN     91.0                   [English Language]
# 54680          NaN      NaN                   [Turkish Language]
# 22415    2050000.0     93.0                   [English Language]
# 28282          NaN      NaN                     [Tamil Language]
# 28216    1400000.0     91.0                   [English Language]
# 70825          NaN     98.0                   [English Language]
# 59819          NaN     90.0                   [English Language]
#
#                         countries  \
# 49623            [France, Serbia]
# 67249  [United States of America]
# 14855  [United States of America]
# 69732  [United Kingdom, Scotland]
# 54680                    [Turkey]
# 22415  [United States of America]
# 28282                     [India]
# 28216  [United States of America]
# 70825                 [Australia]
# 59819  [United States of America]
#
#                                                   genres  \
# 49623            [Drama, Comedy, World cinema, Art film]
# 67249  [Thriller, Crime Fiction, Horror, Psychologica...
# 14855   [Thriller, Crime Thriller, Action, Drama, Heist]
# 69732          [Action/Adventure, Heist, Action, Comedy]
# 54680  [Action, Historical fiction, Adventure, War film]
# 22415                                            [Drama]
# 28282                                           [Action]
# 28216                           [Drama, Medical fiction]
# 70825                                            [Drama]
# 59819                       [Horror, Haunted House Film]
#
#                                             directors  \
# 49623                            [[[Emir Kusturica]]]
# 67249                           [[[Martin Scorsese]]]
# 14855                              [[[Nimród Antal]]]
# 69732                              [[[Bill Forsyth]]]
# 54680                                   [Atıf Yılmaz]
# 22415      [[[David Miller (director)|David Miller]]]
# 28282  [[[R. Sundarrajan (director)|R. Sundarrajan]]]
# 28216                          [[[Nunnally Johnson]]]
# 70825                        [[[Alkinos Tsilimidos]]]
# 59819                                [John Murlowski]
#
#                                                  summary
# 49623  Set in Zlatibor District, an old man named Živ...
# 67249  In 1954, two U.S. Marshals, Edward "Teddy" Dan...
# 14855  Ty Hackett , an armed service veteran, is now ...
# 69732  Ronnie ([[Robert Buchanan , Wal , Andy  and Vi...
# 54680  Hüseyin Gazi, the father of Battal Gazi, is ki...
# 22415  Los Angeles teenager Gail Macaulay is going st...
# 28282  [[More plot|date=December 2021]]A rich estate ...
# 28216  Eve White is a timid, self-effacing wife and m...
# 70825  Geoff Brewster is seeing out his final days at...
# 59819  Keyes Terry is an art photographer who is give...

# %%
old_shape = df_additional[df_additional["summary"] != ''].shape[0]
new_shape = summary_df.shape[0]
print("Adding the Wikipedia dataset increased the number of summaries from " + str(old_shape) + " to " + str(new_shape) +".")
print("This is an increase of " + str(np.round(new_shape/old_shape * 100)) + "%.")
# Out:
# Adding the Wikipedia dataset increased the number of summaries from 39586 to 52136.
# This is an increase of 132.0%.
